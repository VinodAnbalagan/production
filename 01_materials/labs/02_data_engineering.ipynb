# %%
# %load_ext dotenv
# %dotenv

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss dask vs pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance and we will use the API provided by the library yfinance.
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# ![Medallion Architecture (DataBicks)](./images/02_medallion_architecture.png)
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class that will help us control the process of obtaining and transforming our data.
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# # Download Data
#
# Download the [Stock Market Dataset from Kaggle](https://www.kaggle.com/datasets/jacksoncrow/stock-market-dataset). Note that you may be required to register for a free account.
#
# Extract all files into the directory: `./05_src/data/prices_csv/`
#
# Your folder structure should include the following paths:
#
# + `05_src/data/prices_csv/etfs`
# + `05_src/data/prices_csv/stocks`

# %%
import pandas as pd
import os
import sys
from glob import glob

sys.path.append(os.getenv('SRC_DIR'))

from utils.logger import get_logger
_logs = get_logger(__name__)

# %% [markdown]
# A few things to notice in the code chunk above:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager (pip in this case, but could be conda, poetry, etc.)
# + The command `sys.path.append("../05_src/)` will add the `../05_src/` directory to the path in the Notebook's kernel. This way, we can use our modules as part of the notebook.
# + Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by the documentation.

# %% [markdown]
# Now, to load the historical price data for stocks and ETFs, we could use:

# %%
import random

stock_files = glob(os.path.join(os.getenv('SRC_DIR'), "data/prices_csv/stocks/*.csv"))

random.seed(42)
stock_files = random.sample(stock_files, 60)

dt_list = []
for s_file in stock_files:
    _logs.info(f"Reading file: {s_file}")
    dt = pd.read_csv(s_file).assign(
        source = os.path.basename(s_file),
        ticker = os.path.basename(s_file).replace('.csv', ''),
        Date = lambda x: pd.to_datetime(x['Date'])
    )
    dt_list.append(dt)
stock_prices = pd.concat(dt_list, axis = 0, ignore_index = True)
# Out:
# 2025-06-08 12:29:19,906, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/HCM.csv
# 2025-06-08 12:29:19,980, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ATHM.csv
# 2025-06-08 12:29:19,983, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/RILYP.csv
# 2025-06-08 12:29:19,986, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ALDX.csv
# 2025-06-08 12:29:19,989, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/JHG.csv
# 2025-06-08 12:29:19,992, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CHRS.csv
# 2025-06-08 12:29:19,996, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/BKTI.csv
# 2025-06-08 12:29:20,006, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/REFR.csv
# 2025-06-08 12:29:20,013, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/KEN.csv
# 2025-06-08 12:29:20,016, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/MDRRP.csv
# 2025-06-08 12:29:20,018, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/GRF.csv
# 2025-06-08 12:29:20,022, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/KRC.csv
# 2025-06-08 12:29:20,028, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/MICT.csv
# 2025-06-08 12:29:20,032, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AMPY.csv
# 2025-06-08 12:29:20,038, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/A.csv
# 2025-06-08 12:29:20,046, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/WRLSU.csv
# 2025-06-08 12:29:20,049, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PNR.csv
# 2025-06-08 12:29:20,060, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TERP.csv
# 2025-06-08 12:29:20,065, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TMSR.csv
# 2025-06-08 12:29:20,069, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TDJ.csv
# 2025-06-08 12:29:20,074, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CIK.csv
# 2025-06-08 12:29:20,083, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/SMBC.csv
# 2025-06-08 12:29:20,091, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CNSP.csv
# 2025-06-08 12:29:20,093, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/BLK.csv
# 2025-06-08 12:29:20,100, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CLNC.csv
# 2025-06-08 12:29:20,104, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AOSL.csv
# 2025-06-08 12:29:20,108, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/LYV.csv
# 2025-06-08 12:29:20,114, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/IX.csv
# 2025-06-08 12:29:20,121, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AWRE.csv
# 2025-06-08 12:29:20,128, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/KNX.csv
# 2025-06-08 12:29:20,136, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TRXC.csv
# 2025-06-08 12:29:20,144, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CVCY.csv
# 2025-06-08 12:29:20,150, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/UVE.csv
# 2025-06-08 12:29:20,157, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/HCKT.csv
# 2025-06-08 12:29:20,163, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TFSL.csv
# 2025-06-08 12:29:20,168, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ACB.csv
# 2025-06-08 12:29:20,174, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AXP.csv
# 2025-06-08 12:29:20,184, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/GLG.csv
# 2025-06-08 12:29:20,188, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/MFO.csv
# 2025-06-08 12:29:20,192, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PCB.csv
# 2025-06-08 12:29:20,195, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/IPDN.csv
# 2025-06-08 12:29:20,198, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/DTW.csv
# 2025-06-08 12:29:20,202, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/IQV.csv
# 2025-06-08 12:29:20,205, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/EVRI.csv
# 2025-06-08 12:29:20,209, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/LIVE.csv
# 2025-06-08 12:29:20,214, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/KZR.csv
# 2025-06-08 12:29:20,216, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/SO.csv
# 2025-06-08 12:29:20,226, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/INFY.csv
# 2025-06-08 12:29:20,233, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/BSE.csv
# 2025-06-08 12:29:20,238, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PSN.csv
# 2025-06-08 12:29:20,242, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TNAV.csv
# 2025-06-08 12:29:20,245, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/APTX.csv
# 2025-06-08 12:29:20,248, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/LAZY.csv
# 2025-06-08 12:29:20,250, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/DK.csv
# 2025-06-08 12:29:20,255, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ZEUS.csv
# 2025-06-08 12:29:20,269, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/IRBT.csv
# 2025-06-08 12:29:20,274, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AMAT.csv
# 2025-06-08 12:29:20,284, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PSB.csv
# 2025-06-08 12:29:20,292, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CTSO.csv
# 2025-06-08 12:29:20,296, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/UEC.csv

# %% [markdown]
# Verify the structure of the `stock_prices` data:

# %%
stock_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230273 entries, 0 to 230272
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date       230273 non-null  datetime64[ns]
#  1   Open       230260 non-null  float64
#  2   High       230260 non-null  float64
#  3   Low        230260 non-null  float64
#  4   Close      230260 non-null  float64
#  5   Adj Close  230260 non-null  float64
#  6   Volume     230260 non-null  float64
#  7   source     230273 non-null  object
#  8   ticker     230273 non-null  object
# dtypes: datetime64[ns](1), float64(6), object(2)
# memory usage: 15.8+ MB

# %% [markdown]
# We can subset our ticker data set using standard indexing techniques. A good reference for this type of data manipulation is Panda's [Documentation](https://pandas.pydata.org/docs/user_guide/indexing.html#indexing-and-selecting-data) and [Cookbook](https://pandas.pydata.org/docs/user_guide/cookbook.html#cookbook-selection).

# %% [markdown]
# From the subset data frame, select one column and convert to list.

# %%
select_tickers = stock_prices['ticker'].unique().tolist()
select_tickers
# Out:
# ['HCM',
#  'ATHM',
#  'RILYP',
#  'ALDX',
#  'JHG',
#  'CHRS',
#  'BKTI',
#  'REFR',
#  'KEN',
#  'MDRRP',
#  'GRF',
#  'KRC',
#  'MICT',
#  'AMPY',
#  'A',
#  'WRLSU',
#  'PNR',
#  'TERP',
#  'TMSR',
#  'TDJ',
#  'CIK',
#  'SMBC',
#  'CNSP',
#  'BLK',
#  'CLNC',
#  'AOSL',
#  'LYV',
#  'IX',
#  'AWRE',
#  'KNX',
#  'TRXC',
#  'CVCY',
#  'UVE',
#  'HCKT',
#  'TFSL',
#  'ACB',
#  'AXP',
#  'GLG',
#  'MFO',
#  'PCB',
#  'IPDN',
#  'DTW',
#  'IQV',
#  'EVRI',
#  'LIVE',
#  'KZR',
#  'SO',
#  'INFY',
#  'BSE',
#  'PSN',
#  'TNAV',
#  'APTX',
#  'LAZY',
#  'DK',
#  'ZEUS',
#  'IRBT',
#  'AMAT',
#  'PSB',
#  'CTSO',
#  'UEC']

# %% [markdown]
# # Storing Data in CSV

# %% [markdown]
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parqruet, by measuring their performance:
#
#     - Time to save.
#     - Space required.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %%
import time
import shutil

# %%
temp = os.getenv("TEMP_DATA")
csv_dir = os.path.join(temp, "csv")
shutil.rmtree(csv_dir, ignore_errors=True)
stock_csv = os.path.join(csv_dir, "stock_px.csv")
os.makedirs(csv_dir, exist_ok=True)

# %%
start = time.time()
stock_prices.to_csv(stock_csv, index = False)
end = time.time()

_logs.info(f'Writing data ({stock_prices.shape}) to csv took {end - start} seconds.')
_logs.info(f'CSV file size { os.path.getsize(stock_csv)*1e-6 } MB')
# Out:
# 2025-06-08 12:44:42,363, 473192941.py, 5, INFO, Writing data ((230273, 9)) to csv took 0.9028160572052002 seconds.
# 2025-06-08 12:44:42,364, 473192941.py, 6, INFO, CSV file size 25.988193 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Dask
#
# We can work with with large data sets and parquet files. In fact, recent versions of pandas support pyarrow data types and future versions will require a pyarrow backend. The pyarrow library is an interface between Python and the Appache Arrow project. The [parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are projects of the Apache Foundation.
#
# However, Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on pandas-like dataframes. It is also relatively easy to use, bridging a gap between pandas and Spark.

# %%
import dask.dataframe as dd

parquet_dir = os.path.join(temp, "parquet")
shutil.rmtree(parquet_dir, ignore_errors=True)
os.makedirs(parquet_dir, exist_ok=True)

# %%
px_dd = dd.from_pandas(stock_prices, npartitions = len(select_tickers))

start = time.time()
px_dd.to_parquet(parquet_dir, engine = "pyarrow")
end = time.time()

_logs.info(f'Writing dd ({stock_prices.shape}) to parquet took {end - start} seconds.')
_logs.info(f'Parquet file size { get_dir_size(parquet_dir)*1e-6 } MB')
# Out:
# 2025-06-08 12:45:03,086, 817812245.py, 7, INFO, Writing dd ((230273, 9)) to parquet took 0.6726160049438477 seconds.
# 2025-06-08 12:45:03,087, 817812245.py, 8, INFO, Parquet file size 8.883424999999999 MB

# %% [markdown]
# ### Parquet files and Dask Dataframes
#
# + Parquet files are immutable: once written, they cannot be modified.
# + Dask DataFrames are a useful implementation to manipulate data stored in parquets.
# + Parquet and Dask are not the same: parquet is a file format that can be accessed by many applications and programming languages (Python, R, PowerBI, etc.), while Dask is a package in Python to work with large datasets using distributed computation.
# + **Dask is not for everything** (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
#
#     - Consider cases suchas small to large joins, where the small dataframe fits in memory, but the large one does not.
#     - If possible, use pandas: reduce, then use pandas.
#     - Pandas performance tips apply to Dask.
#     - Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
#     - Avoid (or minimize) full-data shuffling: indexing is an expensive operations.
#     - Some joins are more expensive than others.
#
#         * Not expensive:
#
#             - Join a Dask DataFrame with a pandas DataFrame.
#             - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#             - Join Dask DataFrames along their indexes.
#
#         * Expensive:
#
#             - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How do we store prices?
#
# + We can store our data as a single blob. This can be difficult to maintain, especially because parquet files are immutable.
# + Strategy: organize data files by ticker and date. Update only latest month.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
stock_prices.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'source',
#        'ticker'],
#       dtype='object')

# %%
for ticker in stock_prices['ticker'].unique():
    ticker_dt = stock_prices[stock_prices['ticker'] == ticker]
    ticker_dt = ticker_dt.assign(Year = ticker_dt.Date.dt.year)
    for yr in ticker_dt['Year'].unique():
        yr_dd = dd.from_pandas(ticker_dt[ticker_dt['Year'] == yr],2)
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        yr_dd.to_parquet(yr_path, engine = "pyarrow")

# %% [markdown]
# Why would we want to store data this way?
#
# + Easier to maintain. We do not update old data, only recent data.
# + We can also access all files as follows.

# %% [markdown]
# # Load, Transform and Save

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to get the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "**/*.parquet"), recursive = True)
dd_px = dd.read_parquet(parquet_files).set_index("ticker")

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work like pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.

# %%
dd_shift = dd_px.groupby('ticker', group_keys=False).apply(
    lambda x: x.assign(Close_lag_1 = x['Close'].shift(1))
)
# Out:
# /var/folders/7m/0k17qvdd3c315qrvwd6pdpch0000gn/T/ipykernel_77904/102405636.py:1: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   dd_shift = dd_px.groupby('ticker', group_keys=False).apply(

# %%
dd_rets = dd_shift.assign(
    Returns = lambda x: x['Close']/x['Close_lag_1'] - 1
)

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                           Date     Open     High      Low    Close Adj Close   Volume  source   Year Close_lag_1  Returns
# npartitions=60
# A               datetime64[ns]  float64  float64  float64  float64   float64  float64  string  int32     float64  float64
# ACB                        ...      ...      ...      ...      ...       ...      ...     ...    ...         ...      ...
# ...                        ...      ...      ...      ...      ...       ...      ...     ...    ...         ...      ...
# ZEUS                       ...      ...      ...      ...      ...       ...      ...     ...    ...         ...      ...
# ZEUS                       ...      ...      ...      ...      ...       ...      ...     ...    ...         ...      ...
# Dask Name: assign, 9 expressions
# Expr=Assign(frame=Assign(frame=GroupByApply(frame=SetIndex(frame=ReadParquetFSSpec(abab79f), _other='ticker', options={}), observed=False, group_keys=False, func=<function <lambda> at 0x1667f7940>, meta=<no_default>, args=(), kwargs={})))

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until they are required.
# + To trigger an execution in dask use `.compute()`.

# %%
dd_rets.compute()
# Out:
#              Date       Open       High        Low      Close  Adj Close  \
# ticker
# A      2015-07-06  39.110001  39.660000  39.080002  39.360001  37.599323
# A      2015-07-07  39.529999  39.790001  39.139999  39.790001  38.010090
# A      2015-07-08  39.480000  39.480000  38.709999  38.750000  37.016602
# A      2015-07-09  39.270000  39.330002  38.910000  38.919998  37.179005
# A      2015-07-10  39.290001  39.439999  39.160000  39.400002  37.637531
# ...           ...        ...        ...        ...        ...        ...
# ZEUS   2003-12-24   6.950000   7.000000   6.880000   6.990000   6.401954
# ZEUS   2003-12-26   7.000000   7.750000   6.800000   7.630000   6.988110
# ZEUS   2003-12-29   7.700000   8.500000   7.670000   8.200000   7.510161
# ZEUS   2003-12-30   8.000000   8.500000   8.000000   8.500000   7.784920
# ZEUS   2003-12-31   8.050000   8.490000   8.010000   8.210000   7.519320
#
#            Volume    source  Year  Close_lag_1   Returns
# ticker
# A       2509400.0     A.csv  2015          NaN       NaN
# A       2927800.0     A.csv  2015    39.360001  0.010925
# A       3391000.0     A.csv  2015    39.790001 -0.026137
# A       2237900.0     A.csv  2015    38.750000  0.004387
# A       2107100.0     A.csv  2015    38.919998  0.012333
# ...           ...       ...   ...          ...       ...
# ZEUS      10700.0  ZEUS.csv  2003     6.870000  0.017467
# ZEUS     179300.0  ZEUS.csv  2003     6.990000  0.091559
# ZEUS     221700.0  ZEUS.csv  2003     7.630000  0.074705
# ZEUS      95600.0  ZEUS.csv  2003     8.200000  0.036585
# ZEUS      55400.0  ZEUS.csv  2003     8.500000 -0.034118
#
# [230273 rows x 11 columns]

# %% [markdown]
# ## Save
#
# + Apply transformations to calculate daily returns
# + Store the enriched data, the silver dataset, in a new directory.
# + Should we keep the same namespace? All columns?

# %%
# CLean up before save
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)
dd_rets.to_parquet(FEATURES_DATA, overwrite = True)

# %% [markdown]
# # Optional: from Jupyter to Command Line
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object Oriented vs Functional Programming
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefit from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/stock_prices/data_manager.py`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %%
from stock_prices.data_manager import DataManager
dm = DataManager()

# %% [markdown]
# Download all prices.

# %%
dm.process_sample_files()
# Out:
# 2025-06-08 13:01:59,550, data_manager.py, 53, INFO, Processing sample of tickers
# 2025-06-08 13:01:59,551, data_manager.py, 64, INFO, Getting file list from ../../05_src/data/prices_csv/
# 2025-06-08 13:01:59,574, data_manager.py, 66, INFO, Found 8050 files in ../../05_src/data/prices/
# 2025-06-08 13:01:59,575, data_manager.py, 74, INFO, Selecting sample of files
# 2025-06-08 13:01:59,576, data_manager.py, 80, INFO, Selected 30 files
# 2025-06-08 13:01:59,577, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/etfs/XITK.csv
# 2025-06-08 13:01:59,577, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/etfs/XITK.csv
# 2025-06-08 13:01:59,583, data_manager.py, 101, INFO, Saving data by year
# 2025-06-08 13:01:59,664, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/EVTC.csv
# 2025-06-08 13:01:59,665, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/EVTC.csv
# 2025-06-08 13:01:59,668, data_manager.py, 101, INFO, Saving data by year
# 2025-06-08 13:01:59,748, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/AGFS.csv
# 2025-06-08 13:01:59,749, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AGFS.csv
# 2025-06-08 13:01:59,752, data_manager.py, 101, INFO, Saving data by year
# 2025-06-08 13:01:59,825, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/NIE.csv
# 2025-06-08 13:01:59,825, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/NIE.csv
# 2025-06-08 13:01:59,829, data_manager.py, 101, INFO, Saving data by year
# 2025-06-08 13:01:59,969, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/IHT.csv
# 2025-06-08 13:01:59,970, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/IHT.csv
# 2025-06-08 13:01:59,979, data_manager.py, 101, INFO, Saving data by year
# 2025-06-08 13:02:00,439, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/VXX.csv
# 2025-06-08 13:02:00,440, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/VXX.csv
# 2025-06-08 13:02:00,442, data_manager.py, 101, INFO, Saving data by year
# 2025-06-08 13:02:00,510, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/etfs/PCEF.csv
# 2025-06-08 13:02:00,510, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/etfs/PCEF.csv
# 2025-06-08 13:02:00,514, data_manager.py, 101, INFO, Saving data by year
# 2025-06-08 13:02:00,624, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/etfs/HEWG.csv
# 2025-06-08 13:02:00,624, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/etfs/HEWG.csv
# 2025-06-08 13:02:00,627, data_manager.py, 101, INFO, Saving data by year
# 2025-06-08 13:02:00,699, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/CHW.csv
# 2025-06-08 13:02:00,699, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CHW.csv
# 2025-06-08 13:02:00,703, data_manager.py, 101, INFO, Saving data by year
# 2025-06-08 13:02:00,841, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/etfs/IUSS.csv
# 2025-06-08 13:02:00,841, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/etfs/IUSS.csv
# 2025-06-08 13:02:00,844, data_manager.py, 101, INFO, Saving data by year
# 2025-06-08 13:02:00,875, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/etfs/ESML.csv
# 2025-06-08 13:02:00,875, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/etfs/ESML.csv
# 2025-06-08 13:02:00,877, data_manager.py, 101, INFO, Saving data by year
# 2025-06-08 13:02:00,938, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/etfs/RHS.csv
# 2025-06-08 13:02:00,939, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/etfs/RHS.csv
# 2025-06-08 13:02:00,944, data_manager.py, 101, INFO, Saving data by year
# 2025-06-08 13:02:01,088, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/etfs/SMDD.csv
# 2025-06-08 13:02:01,089, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/etfs/SMDD.csv
# 2025-06-08 13:02:01,092, data_manager.py, 101, INFO, Saving data by year
# 2025-06-08 13:02:01,202, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/ITCI.csv
# 2025-06-08 13:02:01,202, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ITCI.csv
# 2025-06-08 13:02:01,205, data_manager.py, 101, INFO, Saving data by year
# 2025-06-08 13:02:01,275, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/SSNC.csv
# 2025-06-08 13:02:01,275, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/SSNC.csv
# 2025-06-08 13:02:01,279, data_manager.py, 101, INFO, Saving data by year
# 2025-06-08 13:02:01,387, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/KZR.csv
# 2025-06-08 13:02:01,387, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/KZR.csv
# 2025-06-08 13:02:01,389, data_manager.py, 101, INFO, Saving data by year
# 2025-06-08 13:02:01,430, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/ADMP.csv
# 2025-06-08 13:02:01,430, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ADMP.csv
# 2025-06-08 13:02:01,436, data_manager.py, 101, INFO, Saving data by year
# 2025-06-08 13:02:01,692, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/NEV.csv
# 2025-06-08 13:02:01,692, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/NEV.csv
# 2025-06-08 13:02:01,697, data_manager.py, 101, INFO, Saving data by year
# 2025-06-08 13:02:01,826, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/etfs/FHK.csv
# 2025-06-08 13:02:01,826, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/etfs/FHK.csv
# 2025-06-08 13:02:01,829, data_manager.py, 101, INFO, Saving data by year
# 2025-06-08 13:02:01,927, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/etfs/PIZ.csv
# 2025-06-08 13:02:01,927, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/etfs/PIZ.csv
# 2025-06-08 13:02:01,933, data_manager.py, 101, INFO, Saving data by year
# 2025-06-08 13:02:02,077, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/RQI.csv
# 2025-06-08 13:02:02,077, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/RQI.csv
# 2025-06-08 13:02:02,083, data_manager.py, 101, INFO, Saving data by year
# 2025-06-08 13:02:02,280, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/NNBR.csv
# 2025-06-08 13:02:02,280, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/NNBR.csv
# 2025-06-08 13:02:02,287, data_manager.py, 101, INFO, Saving data by year
# 2025-06-08 13:02:02,550, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/etfs/SPSM.csv
# 2025-06-08 13:02:02,550, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/etfs/SPSM.csv
# 2025-06-08 13:02:02,554, data_manager.py, 101, INFO, Saving data by year
# 2025-06-08 13:02:02,648, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/MOH.csv
# 2025-06-08 13:02:02,648, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/MOH.csv
# 2025-06-08 13:02:02,653, data_manager.py, 101, INFO, Saving data by year
# 2025-06-08 13:02:02,828, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/PFLT.csv
# 2025-06-08 13:02:02,829, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PFLT.csv
# 2025-06-08 13:02:02,832, data_manager.py, 101, INFO, Saving data by year
# 2025-06-08 13:02:02,956, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/SBAC.csv
# 2025-06-08 13:02:02,956, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/SBAC.csv
# 2025-06-08 13:02:02,962, data_manager.py, 101, INFO, Saving data by year
# 2025-06-08 13:02:03,176, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/FUSB.csv
# 2025-06-08 13:02:03,176, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/FUSB.csv
# 2025-06-08 13:02:03,181, data_manager.py, 101, INFO, Saving data by year
# 2025-06-08 13:02:03,394, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/TJX.csv
# 2025-06-08 13:02:03,394, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TJX.csv
# 2025-06-08 13:02:03,402, data_manager.py, 101, INFO, Saving data by year
# 2025-06-08 13:02:03,775, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/BRID.csv
# 2025-06-08 13:02:03,775, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/BRID.csv
# 2025-06-08 13:02:03,785, data_manager.py, 101, INFO, Saving data by year
# 2025-06-08 13:02:04,206, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/etfs/RWL.csv
# 2025-06-08 13:02:04,206, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/etfs/RWL.csv
# 2025-06-08 13:02:04,211, data_manager.py, 101, INFO, Saving data by year

# %% [markdown]
# Finally, add features to the data set and save to a *feature store*.

# %%
dm.featurize()
# Out:
# 2025-06-08 13:02:28,492, data_manager.py, 131, INFO, Creating features data.
# 2025-06-08 13:02:28,493, data_manager.py, 141, INFO, Loading price data from ../../05_src/data/prices/
# 2025-06-08 13:02:28,664, data_manager.py, 150, INFO, Creating features
# /Users/vinodanbalagan/University Of Toronto/production/01_materials/labs/../../05_src/stock_prices/data_manager.py:153: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   features = (price_dd.groupby('ticker', group_keys=False)
# 2025-06-08 13:02:28,668, data_manager.py, 175, INFO, Saving features to ../../05_src/data/features/stock_features
